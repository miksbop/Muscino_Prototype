# %%
from genreifier import predict_genre

# %%
#Does it work for a file in a child directory?
genre =predict_genre('./test_music/test.mp3')
print(genre)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step
# disco

# %%
# How does it fair with a different genre
genre =predict_genre('./test_music/test2.mp3')
print(genre)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# hiphop

# %%
# How about Metal vs Rock
genre =predict_genre('./test_music/test3.mp3')
print(genre)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# metal

# %%
#Does it work for a file in a completely different directory than the script?
#This probably won't work on other people's machines, but it should work on mine LMAO
predict_genre("C:\\Users\\Aidia\\Downloads\\Final Fantasy 6 Music - Dancing Mad (Final Part).mp3")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 'rock'
